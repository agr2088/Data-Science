# %% [markdown]
# # PYTHON PROGRAMMING ASSIGNMENT

# %% [markdown]
# ## Exercise 1: Prime Numbers

# %%
# Finding a prime number using for loop and if conditions along with user input.

number = int(input())
for i in range(2, number):
    if number % i == 0:
        print(f"{number} is not a prime number")
        break
else:
    print(f"{number} is a prime number")
# Out:
# 13 is a prime number

# %% [markdown]
# ## Exercise 2: Product of Random Numbers

# %%
 #Generating two random numbers and verifing the product id and diplaying appropiate message.

import random
a,b = random.randint(1, 12), random.randint(1, 12)
PRODUCT_ID = a * b
user_answer = int(input(f"Please Enter the product of {a} and {b}? "))

if user_answer == PRODUCT_ID:
    print("PRODUCT VERIFICATION SUCCESSFUL")
else:
    print("INVALID. PLEASE VERIFY AGAIN ")
# Out:
# PRODUCT VERIFICATION SUCCESSFUL

# %% [markdown]
# ## Exercise 3: Squares of Even/Odd Numbers

# %%
# Using range function and if conditions to display the square of even & odd numbers.
for i in range(100, 201):
    print(f"{i} squared is {i ** 2} ({'even' if i % 2 == 0 else 'odd'})") 

# Using conditional statement to only include squared numbers that are even only.
for i in range(100, 201):
    if i % 2 == 0:
        print(f"{i} squared is {i ** 2}, even")
# Out:
# 100 squared is 10000 (even)
# 101 squared is 10201 (odd)
# 102 squared is 10404 (even)
# 103 squared is 10609 (odd)
# 104 squared is 10816 (even)
# 105 squared is 11025 (odd)
# 106 squared is 11236 (even)
# 107 squared is 11449 (odd)
# 108 squared is 11664 (even)
# 109 squared is 11881 (odd)
# 110 squared is 12100 (even)
# 111 squared is 12321 (odd)
# 112 squared is 12544 (even)
# 113 squared is 12769 (odd)
# 114 squared is 12996 (even)
# 115 squared is 13225 (odd)
# 116 squared is 13456 (even)
# 117 squared is 13689 (odd)
# 118 squared is 13924 (even)
# 119 squared is 14161 (odd)
# 120 squared is 14400 (even)
# 121 squared is 14641 (odd)
# 122 squared is 14884 (even)
# 123 squared is 15129 (odd)
# 124 squared is 15376 (even)
# 125 squared is 15625 (odd)
# 126 squared is 15876 (even)
# 127 squared is 16129 (odd)
# 128 squared is 16384 (even)
# 129 squared is 16641 (odd)
# 130 squared is 16900 (even)
# 131 squared is 17161 (odd)
# 132 squared is 17424 (even)
# ...

# %% [markdown]
# ## Exercise 4:

# %%
# Caluclating the final hospital bill & applying the discount if the total bill exceeds ₹10,000.

room_charge = 2000 * 4
doctor_fee = 1500
lab_tests = 300 * 3
medicine_cost = 2400

total_bill_before_discount = room_charge + doctor_fee + lab_tests + medicine_cost
discount = total_bill_before_discount * 0.10 if total_bill_before_discount > 10000 else 0
final_bill = total_bill_before_discount - discount

print(f"Total bill: ₹{room_charge} + ₹{doctor_fee} + ₹{lab_tests} + ₹{medicine_cost}")
print(f"Discount: ₹{(total_bill_before_discount * 0.10)}")
print(f"Final Bill: ₹{final_bill:.2f}")
# Out:
# Total bill: ₹8000 + ₹1500 + ₹900 + ₹2400
# Discount: ₹1280.0
# Final Bill: ₹11520.00
