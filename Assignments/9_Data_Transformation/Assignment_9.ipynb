# %% [markdown]
# # Data Preprocessing and Feature Engineering in Machine Learning

# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ppscore as pps
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %% [markdown]
# ## 1. Data Exploration and Loading :

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv("adult_with_headers.csv")
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# ### Basic dataset information

# %%
# Shape of the DataFrame
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# ### Check missing values

# %%
# Data types and non-null counts
df.info()
# Summary statistics for numerical features
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education_num   32561.0      10.080679       2.572720      1.0       9.0
# capital_gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital_loss    32561.0      87.303830     402.960219      0.0       0.0
# hours_per_week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education_num       10.0      12.0       16.0
# capital_gain         0.0       0.0    99999.0
# capital_loss         0.0       0.0     4356.0
# hours_per_week      40.0      45.0       99.0

# %% [markdown]
# ### a. Handling Missing Values
#
# - In the Adult dataset, missing values are often represented as '?'.
# - We can replace these '?' with NaN

# %%
(df ==" ?").sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
# Remove leading/trailing spaces from all object (string) columns
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].str.strip()

# Replace '?' with NaN
df.replace("?", pd.NA, inplace=True)
(df == "?").sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Impute categorical features with mode
for col in ['workclass', 'occupation', 'native_country']:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %% [markdown]
# ### b. Scaling Techniques

# %%
# Separate numerical columns
numerical_cols = df.select_dtypes(exclude="object").columns

# %% [markdown]
# ### Standard Scaling

# %%
standard_scaler = StandardScaler()
df_standard_scaled = df.copy()

df_standard_scaled[numerical_cols] = standard_scaler.fit_transform(df[numerical_cols])

# %% [markdown]
# #### When to Use Standard Scaling:
#
# * Data follows normal distribution
# * Algorithms like Logistic Regression, SVM, PCA
# * Sensitive to variance

# %% [markdown]
# ### Min-Max Scaling

# %%
minmax_scaler = MinMaxScaler()
df_minmax_scaled = df.copy()

df_minmax_scaled[numerical_cols] = minmax_scaler.fit_transform(df[numerical_cols])

# %% [markdown]
# #### When to Use Min-Max Scaling:
#
# * Data not normally distributed
# * Required bounded values (0–1)
# * Algorithms like KNN, Neural Networks

# %% [markdown]
# ## 2. Encoding Techniques :

# %%
# Identify categorical columns (excluding target variable)
categorical_cols = [col for col in df.select_dtypes(include="object").columns if col != 'income']

# %%
# Split based on cardinality
low_cardinality_cols = [col for col in categorical_cols if df[col].nunique() < 5]
high_cardinality_cols = [col for col in categorical_cols if df[col].nunique() >= 5]

# %% [markdown]
# ### One-Hot Encoding(Low Cardinality)

# %%
#for low-cardinality features
df_onehot = pd.get_dummies(df, columns=low_cardinality_cols, drop_first=True)

# %% [markdown]
# #### Pros:
# * No ordinal assumption
# * Works well with linear models
#
# #### Cons:
# * Increases dimensionality
# * Sparse matrix problem

# %% [markdown]
# ### Label Encoding (High Cardinality)

# %%
# Label Encoding for high-cardinality features
le = LabelEncoder()
for col in high_cardinality_cols:
    df_onehot[col] = le.fit_transform(df_onehot[col])

# %%
# Encode target variable
df_onehot['income'] = df_onehot['income'].map({'<=50K': 0, '>50K': 1})

# %% [markdown]
# #### Pros:
#
# * Memory efficient
# * Fast and simple
#
# #### Cons:
#
# * Introduces false ordinal relationship
# * Not ideal for linear models

# %% [markdown]
# ## 3. Feature Engineering :

# %% [markdown]
# ### Creating New Features

# %% [markdown]
# #### Feature 1: Work Experience Indicator

# %%
df_onehot["is_full_time"] = df["hours_per_week"].apply(lambda x: 1 if x >= 40 else 0)

# %% [markdown]
# * Full-time workers are more likely to earn >50K.

# %% [markdown]
# #### Feature 2: Capital Gain Indicator

# %%
df_onehot["has_capital_gain"] = df["capital_gain"].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# * Capital gains strongly correlate with higher income.

# %% [markdown]
# ### Log Transformation of Skewed Feature
# Identifying Skewed Feature:

# %%
df_onehot[numerical_cols].skew().sort_values(ascending=False)
# Out:
# capital_gain      11.953848
# capital_loss       4.594629
# fnlwgt             1.446980
# age                0.558743
# hours_per_week     0.227643
# education_num     -0.311676
# dtype: float64

# %%
# "log1p" Handles zeros safely
df_onehot["capital_gain_log"] = np.log1p(df["capital_gain"])

# %% [markdown]
# #### Justification:
#
# * Reduces skewness
# * Improves model stability
# * Helps linear models learn better patterns

# %% [markdown]
# ### Isolation Forest

# %%
# Selecting numerical features only
numerical_features = df_onehot.select_dtypes(exclude="object")

# Apply Isolation Forest
iso_forest = IsolationForest(
    n_estimators=100,
    contamination=0.05,
    random_state=42
)

outliers = iso_forest.fit_predict(numerical_features)

# Adding outlier flag to dataset
df_onehot["outlier_flag"] = outliers

# %%
# 1 = normal, -1 = outlier
df_onehot["outlier_flag"].value_counts()
# Out:
# outlier_flag
#  1    30933
# -1     1628
# Name: count, dtype: int64

# %% [markdown]
# Isolation Forest was used to identify anomalous observations in the dataset.
# The method isolates outliers by randomly selecting features and split values, making it efficient for high-dimensional data.
# The resulting outlier flag can be used for feature selection or outlier removal.

# %% [markdown]
# ### PPS (Predictive Power Score) Analysis

# %% [markdown]
# PPS computation

# %%
# Calculate PPS matrix
pps_matrix = pps.matrix(df_onehot)

# %%
pps_matrix.pivot(index="x", columns="y", values="ppscore")
# Out:
# y                      age  capital_gain  capital_gain_log  capital_loss  \
# x
# age               1.000000      0.000000          0.000000           0.0
# capital_gain      0.003296      1.000000          0.998032           0.0
# capital_gain_log  0.003711      0.996114          1.000000           0.0
# capital_loss      0.000000      0.000000          0.000000           1.0
# education         0.016926      0.000000          0.000000           0.0
# education_num     0.016926      0.000000          0.000000           0.0
# fnlwgt            0.000000      0.000000          0.000000           0.0
# has_capital_gain  0.000832      0.121097          0.917194           0.0
# hours_per_week    0.002377      0.000000          0.000000           0.0
# income            0.034161      0.000000          0.000000           0.0
# is_full_time      0.000000      0.000000          0.000000           0.0
# marital_status    0.201582      0.000000          0.000000           0.0
# native_country    0.000000      0.000000          0.000000           0.0
# occupation        0.009545      0.000000          0.000000           0.0
# outlier_flag      0.002358      0.000000          0.000000           0.0
# race              0.000000      0.000000          0.000000           0.0
# relationship      0.137371      0.000000          0.000000           0.0
# sex_Male          0.000000      0.000000          0.000000           0.0
# workclass         0.018227      0.000000          0.000000           0.0
#
# y                 education  education_num  fnlwgt  has_capital_gain  \
# x
# age                     0.0       0.000000     0.0          0.000000
# capital_gain            0.0       0.012555     0.0          0.997512
# capital_gain_log        0.0       0.012885     0.0          1.000000
# capital_loss            0.0       0.000000     0.0          0.000000
# education               1.0       1.000000     0.0          0.000000
# education_num           1.0       1.000000     0.0          0.000000
# fnlwgt                  0.0       0.000000     1.0          0.000000
# has_capital_gain        0.0       0.000000     0.0          1.000000
# hours_per_week          0.0       0.000000     0.0          0.000000
# income                  0.0       0.028055     0.0          0.000000
# is_full_time            0.0       0.000000     0.0          0.000000
# marital_status          0.0       0.000000     0.0          0.000000
# native_country          0.0       0.000000     0.0          0.000000
# occupation              0.0       0.075412     0.0          0.000000
# outlier_flag            0.0       0.000000     0.0          0.000000
# race                    0.0       0.000000     0.0          0.000000
# relationship            0.0       0.000000     0.0          0.000000
# sex_Male                0.0       0.000000     0.0          0.000000
# workclass               0.0       0.000000     0.0          0.000000
#
# y                 hours_per_week  income  is_full_time  marital_status  \
# x
# age                     0.000000     0.0           0.0        0.169528
# capital_gain            0.000000     0.0           0.0        0.000000
# capital_gain_log        0.000000     0.0           0.0        0.000000
# capital_loss            0.000000     0.0           0.0        0.000000
# education               0.000000     0.0           0.0        0.000000
# education_num           0.000000     0.0           0.0        0.000000
# fnlwgt                  0.000000     0.0           0.0        0.000000
# has_capital_gain        0.000000     0.0           0.0        0.000000
# hours_per_week          1.000000     0.0           1.0        0.000000
# income                  0.000000     1.0           0.0        0.000000
# is_full_time            0.083906     0.0           1.0        0.000000
# marital_status          0.000000     0.0           0.0        1.000000
# native_country          0.000000     0.0           0.0        0.000000
# occupation              0.000000     0.0           0.0        0.000000
# outlier_flag            0.000000     0.0           0.0        0.000000
# race                    0.000000     0.0           0.0        0.000000
# relationship            0.000000     0.0           0.0        0.295032
# sex_Male                0.000000     0.0           0.0        0.000000
# workclass               0.000000     0.0           0.0        0.000000
#
# y                 native_country  occupation  outlier_flag  race  \
# x
# age                          0.0    0.001871           0.0   0.0
# capital_gain                 0.0    0.000000           0.0   0.0
# capital_gain_log             0.0    0.000000           0.0   0.0
# capital_loss                 0.0    0.000000           0.0   0.0
# education                    0.0    0.024328           0.0   0.0
# education_num                0.0    0.024328           0.0   0.0
# fnlwgt                       0.0    0.000000           0.0   0.0
# has_capital_gain             0.0    0.000000           0.0   0.0
# hours_per_week               0.0    0.003146           0.0   0.0
# income                       0.0    0.000000           0.0   0.0
# is_full_time                 0.0    0.002346           0.0   0.0
# marital_status               0.0    0.000000           0.0   0.0
# native_country               1.0    0.000000           0.0   0.0
# occupation                   0.0    1.000000           0.0   0.0
# outlier_flag                 0.0    0.000271           1.0   0.0
# race                         0.0    0.000000           0.0   1.0
# relationship                 0.0    0.000000           0.0   0.0
# sex_Male                     0.0    0.000000           0.0   0.0
# workclass                    0.0    0.000000           0.0   0.0
#
# y                 relationship  sex_Male  workclass
# x
# age                   0.000829  0.000000        0.0
# capital_gain          0.000000  0.000000        0.0
# capital_gain_log      0.000000  0.000000        0.0
# capital_loss          0.000000  0.000000        0.0
# education             0.000000  0.000000        0.0
# education_num         0.000000  0.000000        0.0
# fnlwgt                0.000000  0.090438        0.0
# has_capital_gain      0.000000  0.000000        0.0
# hours_per_week        0.000000  0.139400        0.0
# income                0.000000  0.000000        0.0
# is_full_time          0.000000  0.222415        0.0
# marital_status        0.132852  0.312799        0.0
# native_country        0.000000  0.000000        0.0
# occupation            0.000000  0.331719        0.0
# outlier_flag          0.000000  0.000000        0.0
# race                  0.000000  0.020532        0.0
# relationship          1.000000  0.400980        0.0
# sex_Male              0.135915  1.000000        0.0
# workclass             0.000000  0.000000        1.0

# %%
pps_pivot = pps_matrix.pivot_table(
    index="x",
    columns="y",
    values="ppscore",
    aggfunc="mean"   # safe aggregation
)

# %% [markdown]
# PPS Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pps_pivot, cmap="coolwarm", linewidths=0.5)
plt.title("PPS Score Heatmap")
plt.show()

# %% [markdown]
# ### Summary
# - Predictive Power Score (PPS) was used to measure both linear and non-linear relationships between features and the target variable.
# - Unlike correlation, PPS captures asymmetric and non-linear dependencies, making it suitable for feature selection.
